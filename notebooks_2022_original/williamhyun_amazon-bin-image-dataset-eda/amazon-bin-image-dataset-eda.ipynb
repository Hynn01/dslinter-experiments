# %% [markdown]
# # Amazon Bin Image Dataset EDA

# %% [markdown]
# ## Import required packages

# %%
# !pip3 install awscli

# %%
import pandas as pd
import matplotlib

# %% [markdown]
# ## Read data file list

# %%
df = pd.read_csv("../input/amazon-bin-image-dataset-file-list/quantity.csv")
df

# %% [markdown]
# ## Load image

# %%
df['location'][46]

# %%
# !aws s3 cp --no-sign-request s3://aft-vbi-pds/bin-images/00024.jpg .

# %%
img = matplotlib.image.imread('00024.jpg')
matplotlib.pyplot.imshow(img)

# %% [markdown]
# ## Statistics

# %%
df.describe()

# %% [markdown]
# ## Histogram

# %%
df.hist(bins=100)

# %% [markdown]
# ## 95% of bins have less than or equal to 12 items

# %%
df.quantile(.95)
